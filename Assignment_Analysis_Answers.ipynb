# %%
import pandas as pd

# %%
dataset= pd.read_csv('Placement.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df=dataset.drop('sl_no',axis=1)
df
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset["salary"].fillna(0)
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         0.0
# Name: salary, Length: 215, dtype: float64

# %% [markdown]
# # 1)Replace the NaN values with correct value. And justify why you havechosen the same.

# %% [markdown]
# #NAN value present in the salary column. It represent the student who doesnt placed, wont get salary. Now we have to remove the NAN as it is not numerical data.

# %%
df['salary']=df['salary'].fillna(0)
df["salary"] = df['salary'].astype(int)

# %% [markdown]
# # we have replaced with 0. we cant able to use mean or median. because if we took mean or median then it represent that not placed student also earning thats the reason for replacing NAN with 0.

# %% [markdown]
# # 2)How many of them are not placed?

# %%
not_placed = df[df['status']=='Not Placed']
print(not_placed)
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# #Ans: As per the report, 67 students were not get placed in a company. I used boolean indexing or dataframe filter pandas technique to selcet the not placed rows alone based on true or false boolean condition.

# %% [markdown]
# # 3)Find the reason for non placement from the dataset?

# %%
# Using Quantative dataset columns comparison between non placed and placed student.
import pandas as pd
placed = df[df['status'] == 'Placed']
not_placed = df[df['status'] == 'Not Placed']

comparison = pd.DataFrame({
    'Placed Mean': placed[['ssc_p','hsc_p','degree_p','etest_p','mba_p']].mean(),
    'Not Placed Mean': not_placed[['ssc_p','hsc_p','degree_p','etest_p','mba_p']].mean()
})
print(comparison)
# Out:
#           Placed Mean  Not Placed Mean
# ssc_p       71.721486        57.544030
# hsc_p       69.926554        58.395522
# degree_p    68.740541        61.134179
# etest_p     73.238041        69.587910
# mba_p       62.579392        61.612836

# %%
#Using qualitative dataset
freq_table = df[['specialisation', 'status']].value_counts()
print("Specialisation vs Status frequencies:")
print(freq_table)

# Most common specialization among non-placed
most_common_nonplaced_spec = not_placed['specialisation'].mode()[0]
print("\nMost common Specialisation among Non-Placed students:", most_common_nonplaced_spec)
# Out:
# Specialisation vs Status frequencies:
# specialisation  status
# Mkt&Fin         Placed        95
# Mkt&HR          Placed        53
#                 Not Placed    42
# Mkt&Fin         Not Placed    25
# Name: count, dtype: int64
#
# Most common Specialisation among Non-Placed students: Mkt&HR

# %% [markdown]
# #Ans : Based on this report, we can see the not placed student scores are not good in secondary and higher school than placed student. Also based on specilisation MKt& Hr department students are most common in non placed student.

# %% [markdown]
# # 4)What kind of relation between salary and mba_p

# %%
df[['salary','mba_p']].cov()
# Out:
#               salary          mba_p
# salary  2.395714e+10  126245.485547
# mba_p   1.262455e+05      34.028376

# %%
df[['salary','mba_p']].corr()
# Out:
#           salary     mba_p
# salary  1.000000  0.139823
# mba_p   0.139823  1.000000

# %% [markdown]
# #Ans: To check relationship between salary and mba_p, i used covaraince and correlation.The covariance of salary and mba_p is 126245.48,its positive covariance and The correlation is 0.139823, its positive correlation.If the MBA percentage is increase, the salary also increase.

# %% [markdown]
# # 5)Which specialization is getting minimum salary?

# %%
Mini_salary=placed.groupby('specialisation')['salary'].min()
print("Minimum salary of placed student based on specialisation:",Mini_salary)
Mean_salary=placed.groupby('specialisation')['salary'].mean()
print("\nAverage salary of placed student based on specialisation:",Mean_salary)
# Out:
# Minimum salary of placed student based on specialisation: specialisation
# Mkt&Fin    200000
# Mkt&HR     200000
# Name: salary, dtype: int64
#
# Average salary of placed student based on specialisation: specialisation
# Mkt&Fin    298852.631579
# Mkt&HR     270377.358491
# Name: salary, dtype: float64

# %% [markdown]
# #Ans: BAsed on Minimum calaculation, both Marketing & Finance and Marketing & HR students who got placed, the lowest salary offered was ₹200,000.but based On average, Marketing & Finance students earned more than Marketing & HR students.This indicates that Finance-related profiles may have slightly higher salary packages compared to HR profiles.

# %% [markdown]
# # 6)How many of them getting above 500000 salary?

# %%
high_salary= df[df['salary'] > 500000]
count = high_salary.shape[0]
print("The students who are getting salary above 500000:", count)
# Out:
# The students who are getting salary above 500000: 3

# %% [markdown]
# #Ans: Three students are getting salary above 500000

# %% [markdown]
# # 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
# One-way ANOVA
f_stat, p_value = stats.f_oneway(df['etest_p'], df['mba_p'])
print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 98.64487057324708
# p-value: 4.672547689133573e-21

# %% [markdown]
# #Ans: p_value should be less than 0.05. here the p-value (4.67) is more than 0.05.So it is not rejecting the null hypothesis.since there is a no
# significant difference between etest_p and mba_p.

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('salary ~ C(degree_t) + C(specialisation) + C(degree_t):C(specialisation)', data=df).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                      sum_sq     df          F    PR(>F)
# C(degree_t)                    7.197891e+10    2.0   1.616216  0.201122
# C(specialisation)              3.815378e+11    1.0  17.134112  0.000051
# C(degree_t):C(specialisation)  1.101264e+10    2.0   0.247278  0.781152
# Residual                       4.653956e+12  209.0        NaN       NaN

# %% [markdown]
# #Ans: I used two way anova, to check the similarity between 2 factors (degree_t,specialisation) as indep and salary as dep. According to the report, degree_t p_value (0.2) >0.05,it is not rejecting the null hypothesis, there is no significance difference. specialisation p_value(0.00005) < 0.05, its rejecting the null hypothesis and there is a significant difference. similarity between the degree_t and specialisation p_value (0.78)>0.05,it is not rejecting the null hypothesis and there is a no significant difference between them.

# %% [markdown]
# # 9)Convert the normal distribution to standard normal distribution for salary column

# %%
mean_salary = df['salary'].mean()
std_salary = df['salary'].std()

# Standardize (z-score)
df['salary_z'] = (df['salary'] - mean_salary) / std_salary

# Check the result
print(df[['salary', 'salary_z']].head())

# %%
from Univariate import Univariate

# %%
Univariate.StdNBgraph(df['salary'])

# %% [markdown]
# #10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
Univariate.get_pdf_probability(df['salary'],700000,900000)

# %% [markdown]
# # 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_rel
sci_tech = df[ df['degree_t'] == 'Sci&Tech']['etest_p']
sci_tech1 = df[ df['degree_t'] == 'Sci&Tech']['mba_p']
ttest_rel(sci_tech,sci_tech1)

# %% [markdown]
# #Ans: At the 5% significance level, the p-value is less than 0.05. Hence, we reject the null hypothesis. There is a significant difference between etest_p and mba_p for Sci&Tech students.

# %% [markdown]
# # 12)Which parameter is highly correlated with salary?

# %%
df.corr(numeric_only=True)['salary'].drop(['salary', 'salary_z'], errors='ignore').sort_values(ascending=False).head(1)

# %% [markdown]
# #Ans: The correlation analysis shows that Secondary School Percentage (ssc_p) has the highest correlation with salary (r = 0.538).This indicates a moderate positive relationship between SSC performance and salary.

# %% [markdown]
# #13) plot any useful graph and explain it.

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df['ssc_p'], df['salary'])
plt.xlabel('SSC Percentage')
plt.ylabel('Salary')
plt.title('Relationship between SSC Percentage and Salary')
plt.show()

# %% [markdown]
# #Ans: The scatter plot shows the relationship between SSC percentage and salary.It can be observed that as the SSC percentage increases, the salary also tends to increase.This indicates a moderate positive correlation between SSC percentage and salary.Hence, students with higher SSC marks generally receive higher salary packages.

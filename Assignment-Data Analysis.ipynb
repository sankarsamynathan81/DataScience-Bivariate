# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("PrePlacement.csv") #load the dataset

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000
# ..         ...    ...      ...            ...    ...         ...     ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       0
#
# [215 rows x 15 columns]

# %% [markdown]
# # Q1: Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
dataset.isnull().sum() #check for null values
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset["salary"].fillna(0) #replace NaN values in salary column with 0 , another way : dataset["salary"]=dataset["salary"].fillna(0)
# Out:
# 0      270000
# 1      200000
# 2      250000
# 3           0
# 4      425000
#         ...
# 210    400000
# 211    275000
# 212    295000
# 213    204000
# 214         0
# Name: salary, Length: 215, dtype: object

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       0.0
#
# [215 rows x 15 columns]

# %%
dataset.isnull().sum() #verify null values again
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Explanation:
#     The salary column contains 67 missing values because those students were not placed.
#     Since non-placed students do not receive any salary,
#     replacing NaN with 0 is meaningful and preserves all records in the dataset.

# %% [markdown]
# # Question-2)How many of them are not placed?

# %%
not_placed=dataset[dataset["status"]=="Not Placed"] #we are loading not-placed students data into one variable

# %%
print('No.of students not placed:',len(not_placed)) #we can see the count using len function
# Out:
# No.of students not placed: 67

# %% [markdown]
# # Explanation:
#     The status column indicates whether a student is placed or not placed.
#     By filtering the dataset for "Not Placed", we found that 67 students were not placed.

# %% [markdown]
# # Question-3)Find the reason for non placement from the dataset?

# %%
not_placed.describe()
# Out:
#             sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p
# count   67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   110.477612  57.544030  58.395522  61.134179  69.587910  61.612836
# std     65.859667   8.394246   9.914090   6.365825  11.930687   5.705689
# min      4.000000  40.890000  37.000000  50.000000  50.000000  51.210000
# 25%     48.500000  52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    107.000000  56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    170.500000  63.000000  64.000000  65.000000  76.500000  65.405000
# max    215.000000  77.800000  82.000000  79.000000  97.000000  75.710000

# %% [markdown]
# # Explanation:
#     The dataset does not contain a specific column mentioning the reason for non-placement.
#     However, after analysing the non-placed students' record, we can see the factor such as,
#     - lower academic percentages,
#     - lower entrance test scores, degree mark also low.

# %% [markdown]
# # Question-4)What kind of relation between salary and mba_p

# %%
from Univariate import Univariate

# %%
quan,qual = Univariate.QuanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status',
#  'salary']

# %%
dataset[quan].corr() #this is overall correlation between all the columns
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000

# %%
correlation=dataset["salary"].corr(dataset["mba_p"]) #specifically see the correlation between salary and mba_p

# %%
print("correlation between salary and mba_p :",correlation)
# Out:
# correlation between salary and mba_p : 0.14587778454705008

# %% [markdown]
# # Explanation:
# The correlation value is 0.1398, which indicates a very weak positive relationship between MBA nad salary.

# %% [markdown]
# # Question-5)Which specialization is getting minimum salary?

# %%
specialization_salary=dataset.groupby(["specialisation"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2461, in GroupBy.mean.<locals>.<lambda>(x)
#    2458 else:
#    2459     result = self._cython_agg_general(
#    2460         "mean",
# -> 2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'MMMMFMMMMFFMFMFFMFMMMFMMFMFMMMMMMMMFMMMMMMMMFMMMMMMFMFFMMFFFMFMMFFMMMFFFMMFFFFMMMMMMFMMFMMMMMMFFMMMFMMFMMFFMMMMMFMMMMMMM' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 specialization_salary=dataset.groupby(["specialisation"]).mean()
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2459, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2452     return self._numba_agg_general(
#    2453         grouped_mean,
#    2454         executor.float_dtype_mapping,
#    2455         engine_kwargs,
#    2456         min_periods=0,
#    2457     )
#    2458 else:
# -> 2459     result = self._cython_agg_general(
#    2460         "mean",
#    2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2002, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1999     return result
#    2001 assert alt is not None
# -> 2002 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003 return result
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1948, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1946     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1947     # preserve the kind of exception that raised
# -> 1948     raise type(err)(msg) from err
#    1950 dtype = ser.dtype
#    1951 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
specialization_salary

# %%
minimum_salary_specialization=specialization_salary.idxmin()

# %%
print("Specialization with minimum salary:",minimum_salary_specialization)
# Out:
# Specialization with minimum salary: Mkt&HR

# %% [markdown]
# # Explanation:
# The average salary of students from Mkt&HR specialization is lower than Mkt&Fin

# %% [markdown]
# # Question-6)How many of them getting above 500000 salary?

# %%
above_500000=dataset[dataset["salary"]>500000] #by filtering above 5,00,000 salary's student's details
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 above_500000=dataset[dataset["salary"]>500000] #by filtering above 5,00,000 salary's student's details
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
#    6136 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6138 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6140 return self._construct_result(res_values, name=res_name)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
above_500000
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
print("Number of students getting salary above 5,00,000:",len(above_500000))
# Out:
# Number of students getting salary above 5,00,000: 3

# %% [markdown]
# # Explanation:
#     There are 3 students who received salaries above 5,00,000.

# %% [markdown]
# # Question-7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
Notes:
    Hypothesis
        1. Null Hypothesis (H0) : There is no significant difference between the means of etest_p and mba_p.
        2. Alternative Hypothesis (H1) : There is a significant difference between the means of etest_p and mba_p

# %%
import scipy.stats as stats

stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=np.float64(98.64487057324708), pvalue=np.float64(4.672547689133573e-21))

# %% [markdown]
# # Explanation:
#     Desicion Rule:
#         if p-value < 0.05 --> reject H0
#         if p-value >=0.05 --> accept H0
#         since p-value < 0.05, reject the null hypothesis. (result=4.672*10 power of -21, so 0.000000000000000000000046)
#         There is a statiscally significant difference between etest_p and mba_p at the 5% significance level.

# %% [markdown]
# # Question-8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
Notes:
    Hypothesis
        1. Null Hypothesis (H0) : There is no significant difference in salary between students belonging to Sci&Tech degree and Mkt&HR specialization.
        2. Alternative Hypothesis (H1) : There is a significant difference in salary between the means these groups.

# %%
from scipy.stats import ttest_ind
group1=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
group2=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]

# %%
stats.f_oneway(group1,group2) #this is oneway classification answer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 stats.f_oneway(group1,group2) #this is oneway classification answer
#
# File C:\Anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     576     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     577     return tuple_to_result(*res)
# --> 579 res = hypotest_fun_out(*samples, **kwds)
#     580 res = result_to_tuple(res, n_out)
#     581 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File C:\Anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:3973, in f_oneway(axis, equal_var, *samples)
#    3966     raise TypeError("Expected a boolean value for 'equal_var'")
#    3968 if equal_var:
#    3969     # Determine the mean of the data, and subtract that from all inputs to a
#    3970     # variance (via sum_of_sq / sq_of_sum) calculation.  Variance is invariant
#    3971     # to a shift in location, and centering all data around zero vastly
#    3972     # improves numerical stability.
# -> 3973     offset = alldata.mean(axis=axis, keepdims=True)
#    3974     alldata = alldata - offset
#    3976     normalized_ss = _square_of_sums(alldata, axis=axis) / bign
#
# File C:\Anaconda3\Lib\site-packages\numpy\_core\_methods.py:136, in _mean(a, axis, dtype, out, keepdims, where)
#     134 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     135 if isinstance(ret, mu.ndarray):
# --> 136     ret = um.true_divide(
#     137             ret, rcount, out=ret, casting='unsafe', subok=False)
#     138     if is_float16_result and out is None:
#     139         ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
t_statistic, p_values = ttest_ind(group1,group2,equal_var=False)#this is another way , but i am not sure which one we need to use here

# %%
print("T_statistic",t_statistic)
print("P_values",p_values)
# Out:
# T_statistic 2.5840582957977127
# P_values 0.011110477852831759

# %% [markdown]
# # Explanation:
#     Decision Rule:
#         If P-value < 0.05 --> Reject H0
#         If P-value >=0.05 --> Accept H0
#         If the obtained p-value is less than 0.05, reject the null hypothesis.
#         otherwise, accept the null hypothesis.

# %% [markdown]
# # Question-9)Convert the normal distribution to standard normal distribution for salary column

# %%
salary = dataset[dataset["salary"]!=0]["salary"]#considering only placed students

# %%
mean=salary.mean()
std=salary.std()
print(mean,std)
# Out:
# 288655.4054054054 93457.45241958875

# %%
dataset["z_score"]=(dataset["salary"]-mean)/std #z-score fomula

# %%
print(dataset[["salary","z_score"]])
# Out:
#        salary   z_score
# 0    270000.0 -0.199614
# 1    200000.0 -0.948618
# 2    250000.0 -0.413615
# 3         0.0 -3.088629
# 4    425000.0  1.458895
# ..        ...       ...
# 210  400000.0  1.191393
# 211  275000.0 -0.146114
# 212  295000.0  0.067888
# 213  204000.0 -0.905818
# 214       0.0 -3.088629
#
# [215 rows x 2 columns]

# %% [markdown]
# # Explanation:
#     z-score conversion tranforms salary values into a standard normal distribution with:
#         - Mean=0
#         - Standard deviation =1
#         salary values were standaridized using the Z-score formula.

# %% [markdown]
# # Question-10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
# Density Polt
import seaborn as sns
x=dataset['salary']
ax = sns.distplot(dataset['salary'],kde=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18864\1683114438.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset['salary'],kde=True)

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18864\2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 get_pdf_probability(dataset['salary'],700000,900000)
#
# Cell In[37], line 11, in get_pdf_probability(dataset, startrange, endrange)
#       9 sample = dataset
#      10 # calculate parameters
# ---> 11 sample_mean =sample.mean()
#      12 sample_std = sample.std()
#      13 print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '...' to numeric

# %%
salary1 = dataset[dataset["salary"]!=0]["salary"] #anotherway without graph using CDF-Cumulative detribution function

# %%
mean1=salary1.mean()
std1=salary1.std()
print(mean1,std1)
# Out:
# 288655.4054054054 93457.45241958875

# %%
from scipy.stats import norm
probability=norm.cdf(900000,mean1,std1)-norm.cdf(700000,mean1,std1)
print("Probability:",probability)
# Out:
# Probability: 5.377445759013888e-06

# %% [markdown]
# # Explanation:
#     -This calculates the probability of observing salaries between 7,00,000 and 9,00,000 assuming a normal distribution.
#     -The probability of salary falling between 7,00,000 and 9,00,000 is approximately 0.00000538, indicating that such salaries are very rare.

# %% [markdown]
# # Question-11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hy pothesis Testing)

# %%
Notes:
    Hypothesis
    1. Null Hypothesis(H0): There is no significant difference between etest_p and mba_p among Sci&Tech students.
    2. Alternative Hypothesis(H1): There is a significant difference between etest_p and mba_p among Sci&Tech students.

# %%
from scipy.stats import ttest_ind
sci=dataset[dataset["degree_t"]=="Sci&Tech"]
etest=sci["etest_p"]
mba=sci["mba_p"]
t_stat,p_value=ttest_ind(etest,mba)
print("T-statistic:",t_stat)
print("P_value",p_value)
if p_value < 0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# T-statistic: 4.532000225151251
# P_value 1.4289217003775636e-05
# Reject Null Hypothesis

# %% [markdown]
# # Explanation:
#     A t-test is used to determine whether the means differ significantly.
#     Based on the obtained p-value, the hypothesis decision was made at the 5% siggnificance level.

# %% [markdown]
# # Question-12)Which parameter is highly correlated with salary?

# %%
dataset[quan].corr() #this is one of the way we can find by the below tabular columns's result
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000

# %%
numeric_data=dataset.select_dtypes(include=["int64","float64"]) #another way to get only numeric columns
print(numeric_data)
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p
# 0        1  67.00  91.00     58.00     55.0  58.80
# 1        2  79.33  78.33     77.48     86.5  66.28
# 2        3  65.00  68.00     64.00     75.0  57.80
# 3        4  56.00  52.00     52.00     66.0  59.43
# 4        5  85.80  73.60     73.30     96.8  55.50
# ..     ...    ...    ...       ...      ...    ...
# 210    211  80.60  82.00     77.60     91.0  74.49
# 211    212  58.00  60.00     72.00     74.0  53.62
# 212    213  67.00  67.00     73.00     59.0  69.72
# 213    214  74.00  66.00     58.00     70.0  60.23
# 214    215  62.00  58.00     53.00     89.0  60.22
#
# [215 rows x 6 columns]

# %%
correlation=numeric_data.corr()

# %%
correlation
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  \
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823
# z_score   0.002543  0.538090  0.452569  0.408371  0.186988  0.139823
#
#             salary   z_score
# sl_no     0.002543  0.002543
# ssc_p     0.538090  0.538090
# hsc_p     0.452569  0.452569
# degree_p  0.408371  0.408371
# etest_p   0.186988  0.186988
# mba_p     0.139823  0.139823
# salary    1.000000  1.000000
# z_score   1.000000  1.000000

# %%
correlation["salary"].sort_values(ascending=False) #which we can get specific column with decending order
# Out:
# salary      1.000000
# z_score     1.000000
# ssc_p       0.538090
# hsc_p       0.452569
# degree_p    0.408371
# etest_p     0.186988
# mba_p       0.139823
# sl_no       0.002543
# Name: salary, dtype: float64

# %% [markdown]
# # Explanation:
#     The parameter having the highest positive correlation value (excluding salary itself and z_score) is identified.
#     ssc_p has the highest correlation with salary among the numerical variables.

# %% [markdown]
# # Question-13) plot any useful graph and explain it.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.scatter(dataset["mba_p"],dataset["salary"])
plt.xlabel("MBA Pass mark")
plt.ylabel("Salary")
plt.title("Relationship between MBA Pass mark and Salary")
plt.show()

# %%
Explanation:
    - Each point represent one student.
    - X-axis shows MBA pass mark.
    - Y-axis shows salary
    - The graph indicates a weak positive relationship.
    - Students with higher MBA pass mark do not always receive higher salaries.
